# %% [markdown]
# # Lawrence OLADEJI's University of Ibadan MSc Project (IBEDC_OGUN): Mean
# Presentation of Machine Learning Algorithm CV Comparison

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %timeit
# %matplotlib inline
sns.set()
# Out:
# C:\Users\USER\anaconda3\envs\Tensor\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\USER\anaconda3\envs\Tensor\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\USER\anaconda3\envs\Tensor\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
df=pd.read_csv("C:/Users/USER/Desktop/Lawrence/UI Msc/Project folder/ibedcogun/resultn.csv")

# %%
df.head()
# Out:
#   Machine Learning Algorithms              Missing Value Method  CV_Std
# 0           Linear Regression         Mean cross validation std   20.88
# 1           Linear Regression       Median cross validation std   21.30
# 2           Linear Regression  interpolate cross validation std   17.06
# 3     Lasso Linear Regression         Mean cross validation std   20.10
# 4     Lasso Linear Regression       Median cross validation std   20.44

# %%
import seaborn
seaborn.set(style = 'whitegrid') 
seaborn.violinplot(x ='CV_Std', y ='Machine Learning Algorithms', data = df, linewidth =3,palette="Set2")
# Out:
# <AxesSubplot:xlabel='CV_Std', ylabel='Machine Learning Algorithms'>

# %%
import seaborn
seaborn.set(style = 'whitegrid') 
seaborn.violinplot(x ='CV_Std', y ='Missing Value Method', data = df,linewidth = 4, palette="Set2")
# Out:
# <AxesSubplot:xlabel='CV_Std', ylabel='Missing Value Method'>
